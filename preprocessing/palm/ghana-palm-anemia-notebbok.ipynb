# %% [markdown]
# # GLANCE Palm Cohort  Anemia & Healthy Baseline (Notebook 1)
#
# ## Clinical Objective
# Standardize laboratory-confirmed Anemia palmar pallor cases and establish an authentic healthy palmar control baseline.
#
# ## Workflow Summary
# 1. **Healthy Control Expansion**: Extracted 1,000 verified open-palmar images from the 11k Hands benchmark (`shyambhu/hands-and-palm-images-dataset`) and merged them with 222 hospital controls from Ghana Mendeley.
# 2. **Anemia Cohort Balancing**: Isolated multi-angle camera burst exposures across 261 verified anemic patients, filtering out synthetic flips and copies to eliminate patient-level leakage.
# 3. **Target Standard**: Standardized output to schema with structured patient identifiers.
#
# ## Output Volume
# - `healthy_palm_control`: 1,222 images
# - `anemia_palmar_pallor`: 1,044 images
# - **Total**: 2,266 verified clinical images

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algeStep 2: Unpack and Scan Archive Contentsbra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-053 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-049 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-057 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-210 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-071 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-192 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-071 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-027 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-076.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-052 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-001 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-090 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-014 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-183.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-182 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-196 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-169 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-200.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-228 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-106 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-027 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-127 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-119.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-110 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-272 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-174 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-014 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-122 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-040 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-183 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-050 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-272 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-099 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-109.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-019 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-153.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-010 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-046 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-009.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-170 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-164 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-075 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-068.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-023.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-087 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-164 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-013 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-045 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-190 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-223 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-123 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-202 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268RA (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-154 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-068 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-236 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-069 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-238 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-077 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-091.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-054 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-041.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-165.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-125 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-018 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-089 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-161.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-188 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-196.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-067 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-222 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-094 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-047 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-055 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268FV (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-133 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-089 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-058 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-246 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-211 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-028 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-070 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-079 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-106 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-237 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-033 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-236 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-109 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-097 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-021 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-234 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-133 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-187 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-179 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-100 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-063 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-172 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-174 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-187 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-176 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-101.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-087 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-044 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-251 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-105 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-014 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-031 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-103 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-061 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-146.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-013.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-183 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-068 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-032 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-163.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-156 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-007 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-009 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-005 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-027 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-056 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-080 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-166 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-167 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-094 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-190 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-260 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-054 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-005 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-105 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-078 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-011 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-005 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-031.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-027 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-020 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-191 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-161 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-009 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-111 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-004 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-109 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-085 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-101 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-128 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-147 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-050 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-051 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-092 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-046 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-093 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-178 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268FV (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-061 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-148 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-007 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-036 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-015.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-145 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-008.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-035 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-029.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-043 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-005.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-256 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-032 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-177 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-116 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-041 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-002 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-075 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-086.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-152 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-128.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-007 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-060 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-045 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-063 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-052 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-018 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-177.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-075 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-026 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-012 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-021 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-261 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-204 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-113 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-103.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-227 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-138 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-006.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-272.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-133 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-015 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-161 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-082.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-014 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-243 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-171 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-133.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-084 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-093 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-206 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-176 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-157 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-256 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-190 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-038 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-114 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-099 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-049 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-103 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-177 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-149 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-076 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-094 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-007.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-178 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-046 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-264.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-016 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-158 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-090 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-045 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-009 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-254 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-014 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-123 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-091 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-186 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-082 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-035 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-011 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-173 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-087 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-043 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-099 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-026 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-196 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-032 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-071 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-061 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-203 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-207 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-084 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-015 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-130 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-008 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-175 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-160 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-015 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-180 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-002 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-248 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-269 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-188 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-005 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-015 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-182 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-235 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-186 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-144 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-025.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-080 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-230.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-137 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-036 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-169 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-014.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-026 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-031.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-106.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-028.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-039 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-109 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-122.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-024 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-238.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-041 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-034 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-063 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-171 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-257 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-178 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-095 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-023 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-231 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-122 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-195.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-033 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-114.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-192.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-271 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-053 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-140 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-083 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-018 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-024 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-112 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-002 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-050 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-010 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-020 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-068 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-036 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-003 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-039 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-049 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-059 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-139 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-023 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-012 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-052 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-192 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-025 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-013 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-170 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-029 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-189 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-007 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-101 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-045 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-122 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-072 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-130.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-151 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-039.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-087 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-245 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-188 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-012 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-012 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-029 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-181 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-167 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-165 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-047 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-057.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-011 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-124.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-079 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-267 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-076 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-057 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-055 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-007 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-094 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-097 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-106 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-171 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-138 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-050 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-121 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-116 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-003 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-084 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-179 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-025 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-236 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-245 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-165 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-193 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-216 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-176 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-078 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-255.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-166 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-149 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-066 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-008 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-054 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-077 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-047 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-203 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-264 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-217 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-242 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-024 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-173 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-124 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-190 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-002 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-061.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-051 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-041 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-091 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-184 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-066 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-041 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-099 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-101 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-193 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-239 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-023 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-001 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268RA (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-015 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-060 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-021 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-016 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-003 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-046.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-223.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-193 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-060 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-024.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-203 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-116 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-023 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-068 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-087 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-164 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-166.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-151 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-146 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-065 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-205 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-002 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-196 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-039 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-033 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-200 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-197 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-030 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-026 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-173 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268FV (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-168 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-001 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-102 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-193 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268FV (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268FV (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-015 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-122 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-009 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-176 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-028.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-162 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-100 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-029 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-266 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-005 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-025 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-085 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-108 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-167 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-166 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-094 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-226 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-236 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-136 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-025 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-118.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-073 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-096.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-025 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-033 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-051 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-191 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-071 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-077 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-025 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-040 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-001 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-081 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-072 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-002 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-007 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-095 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-063 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-093 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-072 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-069 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-047 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-104 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-062 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-101 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-230 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-192 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-154 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-185 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-200 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-075 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-148 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-195 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-212 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-189 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-138.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-144 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-030 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-235 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-244 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-166.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-019 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-147 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-222.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-092 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-182 (10).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-022 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-007 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-090 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-101 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-234 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-060 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-070 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-048 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-201.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-144 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-214 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-160 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-003 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-181 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-059 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-152 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-020 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-118 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-062 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-140.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-268RA (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-021 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-134 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-055 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-037 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-204 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-019.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-123 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-062.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-163 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-014 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-051 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-178 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-056 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-027 (12).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-026.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-056 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-209 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-123 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-096 (2).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-011.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-092 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-105 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-082 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-229 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-019 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-199 (6).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-193 (8).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-194 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Anemic-Pa-009 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-096 (11).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-035 (7).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-032 (9).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-075 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-022.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-105 (5).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-235.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-061.png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-101 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-229 (4).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-001 (3).png
# /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-048 (4).png
# ...
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010148.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004915.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001675.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011303.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007296.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002563.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010567.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011407.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003226.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011557.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004229.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010407.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000977.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001726.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011724.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003764.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009385.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002942.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004977.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003223.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008494.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005827.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004458.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011045.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002275.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011562.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009059.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000520.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009687.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004459.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002443.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008391.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007795.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008862.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008407.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005204.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006817.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001979.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009095.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005782.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001097.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008988.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008628.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010208.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005549.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002383.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011441.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006555.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004722.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000513.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006986.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006272.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010002.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002717.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003158.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004309.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007678.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011638.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000135.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008173.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003756.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005121.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004887.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011221.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004888.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004781.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005467.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008526.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003940.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008791.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005917.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006673.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004052.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011497.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007111.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009480.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003790.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011173.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000285.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006608.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010500.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011288.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011353.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009739.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002297.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009512.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004058.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001128.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009806.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001934.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009837.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010852.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010800.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002924.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002977.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002664.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009823.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011671.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004092.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002220.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001935.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004839.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011017.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002528.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011247.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001874.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007600.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000903.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006065.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009866.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003714.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002054.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008819.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001579.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010969.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005259.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005391.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006332.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003506.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011000.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0008286.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004141.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003432.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002983.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002882.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009730.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004117.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000679.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004211.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009259.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010440.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005557.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007771.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005456.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011541.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000884.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006896.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004158.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006805.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002120.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009765.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004841.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005720.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002579.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010037.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0009900.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002593.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003144.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004439.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000097.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007737.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010481.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006445.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0003638.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004629.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005566.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002884.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0010804.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001759.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005353.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005399.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007623.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0004412.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007840.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0007077.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006461.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0006140.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011589.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005207.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000672.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0000809.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0001670.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0005232.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0011285.jpg
# /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset/Hands/Hands/Hand_0002155.jpg

# %%
#Step 2: Unpack and Scan Archive Contents
import os
import shutil
from pathlib import Path

# Adjust INPUT_DIR to match your Kaggle input path
INPUT_DIR = Path('/kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia')
EXTRACT_DIR = Path('/kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia')
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

# Unpack if uploaded as RAR/ZIP
for archive in INPUT_DIR.glob('*'):
    if archive.suffix.lower() == '.rar':
        # !unrar x -o+ "{archive}" "{EXTRACT_DIR}"
    elif archive.suffix.lower() == '.zip':
        shutil.unpack_archive(archive, EXTRACT_DIR)

# Scan structure
found_files = list(EXTRACT_DIR.rglob('*'))
print(f"Total extracted files/dirs: {len(found_files)}")
for p in [f for f in found_files if f.is_file()][:15]:
    print(p.relative_to(EXTRACT_DIR))
# Out:
# Total extracted files/dirs: 4261
# Palm/AnemicP-053 (9).png
# Palm/AnemicP-042 (11).png
# Palm/AnemicP-049 (8).png
# Palm/AnemicP-057 (5).png
# Palm/AnemicP-210 (2).png
# Palm/Non-AnemicP-071 (3).png
# Palm/Non-AnemicP-192 (3).png
# Palm/AnemicP-071 (7).png
# Palm/Non-anemic-Pa-017 (4).png
# Palm/Non-anemic-Pa-017 (2).png
# Palm/AnemicP-027 (10).png
# Palm/Non-AnemicP-076.png
# Palm/AnemicP-052 (10).png
# Palm/AnemicP-001 (7).png
# Palm/AnemicP-090 (5).png

# %%
#Step 3 — Extract Base Patient IDs, Validate Images
import re
import hashlib
import pandas as pd
import shutil
from pathlib import Path
from PIL import Image

search_root = EXTRACT_DIR if 'EXTRACT_DIR' in globals() and EXTRACT_DIR.exists() else Path('/kaggle/input')
IMG_EXTS = {'.png', '.jpg', '.jpeg'}
records = []

for p in search_root.rglob('*'):
    if not p.is_file() or p.suffix.lower() not in IMG_EXTS:
        continue

    stem = p.stem.strip()
    stem_lower = stem.lower()
    if 'non-anemic' in stem_lower:
        label = '0_non_anemic'
    elif 'anemic' in stem_lower:
        label = '1_anemic'
    else:
        continue

    m = re.match(r'^(.*?)(?:\s*\(\d+\))?$', stem)
    base_id = m.group(1).strip() if m else stem
    is_original_capture = bool(not re.search(r'\(\d+\)$', stem))

    with open(p, 'rb') as f:
        md5 = hashlib.md5(f.read()).hexdigest()

    try:
        with Image.open(p) as im:
            w, h = im.size
            is_valid = True
    except Exception:
        w, h, is_valid = None, None, False

    records.append({
        'file_name': p.name,
        'file_path': str(p),
        'raw_stem': stem,
        'base_patient_id': f"GHANA_{base_id.upper()}",
        'raw_label': label,
        'is_original_capture': is_original_capture,
        'width': w,
        'height': h,
        'is_valid_image': is_valid,
        'md5': md5
    })

df_parsed = pd.DataFrame(records)
print(f"Total images scanned: {len(df_parsed)}")
# Out:
# Total images scanned: 4260

# %%
df_parsed = df_parsed[df_parsed['is_valid_image']].copy()
print(f"Total valid images: {len(df_parsed)}")
# Out:
# Total valid images: 4260

# %%
def extract_true_patient_id(raw_stem: str) -> str:
    s = raw_stem.strip()
    s = re.sub(r'[\s\-_]*copy.*$', '', s, flags=re.IGNORECASE)
    s = re.sub(r'\s*\(\d+\)', '', s)
    s = re.sub(r'(FV|RA|FLIP|ROT\d+|AUG\d+|_v\d+)$', '', s, flags=re.IGNORECASE)
    s = re.sub(r'[\s_]+', '-', s).strip('-')
    return f"GHANA_{s.upper()}"

df_parsed['strict_patient_id'] = df_parsed['raw_stem'].apply(extract_true_patient_id)

print("Unique IDs before regex fix:", df_parsed['base_patient_id'].nunique())
print("Unique IDs after strict regex fix:", df_parsed['strict_patient_id'].nunique())
# Out:
# Unique IDs before regex fix: 528
# Unique IDs after strict regex fix: 525

# %%
clean_strict_df = (
    df_parsed.sort_values(by=['strict_patient_id', 'is_original_capture'], ascending=[True, False])
    .drop_duplicates(subset=['strict_patient_id'], keep='first')
    .reset_index(drop=True)
)
print(f"Unique patients after dedup: {len(clean_strict_df)}")
# Out:
# Unique patients after dedup: 525

# %%
FINAL_PALM_DIR = Path('/kaggle/working/GLANCE_palm_ghana')
if FINAL_PALM_DIR.exists():
    shutil.rmtree(FINAL_PALM_DIR)
FINAL_PALM_DIR.mkdir(parents=True, exist_ok=True)

final_rows = []
for idx, row in clean_strict_df.iterrows():
    src_path = Path(row['file_path'])
    new_name = f"ghana_palm_{idx:04d}{src_path.suffix.lower()}"
    dest_path = FINAL_PALM_DIR / new_name
    shutil.copy2(src_path, dest_path)

    condition = 'anemia_palmar_pallor' if row['raw_label'] == '1_anemic' else 'healthy_palm_control'
    final_rows.append({
        'source_dataset': 'ghana_palpable_palm_anemia',
        'file_name': new_name,
        'file_path': str(dest_path),
        'image_stem': dest_path.stem,
        'patient_id': row['strict_patient_id'],
        'clinical_condition': condition,
        'annotation_stage': None,
        'oral_site': None,
        'body_location': 'palm',
        'capture_type': 'smartphone_hospital',
        'width': row['width'],
        'height': row['height'],
        'is_valid_image': True,
        'annotation_count': 0,
        'total_annotated_points': 0
    })

standardized_ghana_df = pd.DataFrame(final_rows)

# %%
standardized_ghana_df.to_csv('/kaggle/working/ghana_palm_standardized.csv', index=False)

print("\n--- Final Clean Patient-Level Dataset ---")
print(f"Total Unique Patients: {len(standardized_ghana_df)}")
print(standardized_ghana_df['clinical_condition'].value_counts())
# Out:
# --- Final Clean Patient-Level Dataset ---
# Total Unique Patients: 525
# clinical_condition
# anemia_palmar_pallor    303
# healthy_palm_control    222
# Name: count, dtype: int64

# %%
import kagglehub

# Dataset automatically download 
hands_path = kagglehub.dataset_download("shyambhu/hands-and-palm-images-dataset")
print(f"Downloaded directly to: {hands_path}")
# Out:
# Downloaded directly to: /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset

# %%
import os
import shutil
import pandas as pd
from pathlib import Path
from PIL import Image
import kagglehub

# 1. Download / locate 11k Hands dataset
hands_path = kagglehub.dataset_download("shyambhu/hands-and-palm-images-dataset")
print(f"Dataset path: {hands_path}")

HANDS_ROOT = Path(hands_path)
DEST_DIR = Path('/kaggle/working/GLANCE_palm_ghana')
DEST_DIR.mkdir(parents=True, exist_ok=True)

# 2. Locate metadata CSV
csv_candidates = list(HANDS_ROOT.rglob('*.csv'))
assert len(csv_candidates) > 0, "Metadata CSV nahi mili!"
meta_csv_path = csv_candidates[0]
meta_df = pd.read_csv(meta_csv_path)

print(f"Metadata file: {meta_csv_path.name} | Total records: {len(meta_df)}")

# 3. Filter strictly 'palmar' (open palm)
aspect_col = [c for c in meta_df.columns if any(k in c.lower() for k in ['aspect', 'side'])][0]
palmar_df = meta_df[meta_df[aspect_col].str.contains('palmar', case=False, na=False)].copy()
print(f"Total authentic palmar images available: {len(palmar_df)}")

# 4. Target exactly 1,000 images
SAMPLE_TARGET = 1000
sampled_controls = palmar_df.sample(n=min(SAMPLE_TARGET, len(palmar_df)), random_state=42).reset_index(drop=True)

filename_col = [c for c in sampled_controls.columns if any(k in c.lower() for k in ['name', 'file', 'image'])][0]
id_col = [c for c in sampled_controls.columns if c.lower() == 'id'][0] if any(c.lower() == 'id' for c in sampled_controls.columns) else None

# 5. Copy to standardized schema
new_records = []
print(f"Extracting and copying {len(sampled_controls)} palmar controls...")

for idx, row in sampled_controls.iterrows():
    img_name = str(row[filename_col]).strip()
    found_files = list(HANDS_ROOT.rglob(f"*{img_name}*"))
    if not found_files or not found_files[0].is_file():
        continue
    
    src_path = found_files[0]
    dest_name = f"hands11k_palm_{idx:04d}{src_path.suffix.lower()}"
    dest_path = DEST_DIR / dest_name
    
    shutil.copy2(src_path, dest_path)
    
    try:
        with Image.open(src_path) as im:
            w, h = im.size
            is_valid = True
    except Exception:
        w, h, is_valid = None, None, False

    subj_id = f"SUBJ_{row[id_col]:03d}" if id_col else f"SUBJ_{idx:03d}"

    new_records.append({
        'source_dataset': '11k_hands_afifi',
        'file_name': dest_name,
        'file_path': str(dest_path),
        'image_stem': dest_path.stem,
        'patient_id': f"HANDS11K_{subj_id}",
        'clinical_condition': 'healthy_palm_control',
        'annotation_stage': None,
        'oral_site': None,
        'body_location': 'palm',
        'capture_type': 'controlled_camera',
        'width': w,
        'height': h,
        'is_valid_image': is_valid,
        'annotation_count': 0,
        'total_annotated_points': 0
    })

# 6. Merge with existing Ghana CSV
ghana_csv = Path('/kaggle/working/ghana_palm_standardized.csv')
if ghana_csv.exists():
    df_existing = pd.read_csv(ghana_csv)
    df_existing = df_existing[df_existing['source_dataset'] != '11k_hands_afifi']
else:
    df_existing = pd.DataFrame()

df_merged = pd.concat([df_existing, pd.DataFrame(new_records)], ignore_index=True)
df_merged.to_csv(ghana_csv, index=False)

print("\n" + "=" * 50)
print("HEALTHY PALM UPDATE COMPLETE (1000 TARGET)")
print("=" * 50)
print(f"Added from 11k Hands: {len(new_records)}")
print("\nFinal Class Breakdown in Notebook 1:")
print(df_merged['clinical_condition'].value_counts())
# Out:
# Dataset path: /kaggle/input/datasets/shyambhu/hands-and-palm-images-dataset
# Metadata file: HandInfo.csv | Total records: 11076
# Total authentic palmar images available: 5396
# Extracting and copying 1000 palmar controls...
#
# ==================================================
# HEALTHY PALM UPDATE COMPLETE (1000 TARGET)
# ==================================================
# Added from 11k Hands: 1000
#
# Final Class Breakdown in Notebook 1:
# clinical_condition
# healthy_palm_control    1222
# anemia_palmar_pallor     303
# Name: count, dtype: int64

# %%
import os
from pathlib import Path

print("=== Scanning /kaggle/input top-level directories ===")
input_dirs = [p for p in Path('/kaggle/input').iterdir() if p.is_dir()]
for d in input_dirs:
    print(f"Directory: {d}")

print("\n=== Locating Ghana dataset paths ===")
ghana_matches = [p for p in Path('/kaggle/input').rglob('*ghana*') if p.is_dir()]

if ghana_matches:
    for g_path in ghana_matches:
        print(f"\nFound Ghana directory: {g_path}")
        print("Sample sub-items:")
        sub_items = list(g_path.glob('*'))[:15]
        for item in sub_items:
            print(f"  - {item.name} ({'Folder' if item.is_dir() else 'File'})")
else:
    print("No directory matching 'ghana' found in /kaggle/input.")

print("\n=== Checking image extensions in /kaggle/input ===")
img_exts = {'.jpg', '.jpeg', '.png'}
sample_images = []
for p in Path('/kaggle/input').rglob('*'):
    if p.is_file() and p.suffix.lower() in img_exts and 'hands' not in str(p).lower():
        sample_images.append(p)
        if len(sample_images) >= 10:
            break

print(f"Found {len(sample_images)} sample non-11k-hands image paths:")
for img_p in sample_images:
    print(f"  {img_p}")
# Out:
# === Scanning /kaggle/input top-level directories ===
# Directory: /kaggle/input/datasets
#
# === Locating Ghana dataset paths ===
#
# Found Ghana directory: /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia
# Sample sub-items:
#   - Palm (Folder)
#
# === Checking image extensions in /kaggle/input ===
# Found 10 sample non-11k-hands image paths:
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-053 (9).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-042 (11).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-049 (8).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-057 (5).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-210 (2).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-071 (3).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-AnemicP-192 (3).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/AnemicP-071 (7).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (4).png
#   /kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm/Non-anemic-Pa-017 (2).png

# %%
import os
import shutil
import re
from pathlib import Path
from PIL import Image
import pandas as pd

# 1. Source and Destination Directories
PALM_SOURCE_DIR = Path('/kaggle/input/datasets/shahrozkhalid11/ghana-palm-anemia/Palm')
DEST_DIR = Path('/kaggle/working/GLANCE_palm_ghana')
DEST_DIR.mkdir(parents=True, exist_ok=True)

# 2. Load Existing Standardized Registry and Retain Healthy Controls (1222)
csv_path = Path('/kaggle/working/ghana_palm_standardized.csv')
assert csv_path.exists(), "Standardized registry CSV not found in /kaggle/working!"

df_current = pd.read_csv(csv_path)
df_healthy = df_current[df_current['clinical_condition'] == 'healthy_palm_control'].copy()
print(f"Retained healthy palm controls: {len(df_healthy)}")

# 3. Locate and Filter All Anemic Captures
img_exts = {'.png', '.jpg', '.jpeg'}
anemic_files = [
    p for p in PALM_SOURCE_DIR.iterdir()
    if p.is_file() and p.suffix.lower() in img_exts and 'anemicp-' in p.name.lower()
]

print(f"Total raw anemic files found in Palm folder: {len(anemic_files)}")

records_anemia = []
patient_burst_counter = {}

for p in sorted(anemic_files):
    stem = p.stem.lower()

    # Drop explicitly marked synthetic rotations or copies
    if any(artifact in stem for artifact in ['copy', 'ra', 'fv', 'rot']):
        continue

    # Extract clean Patient ID: matches e.g. "AnemicP-053"
    match = re.search(r'anemicp-(\d+)', stem)
    if not match:
        continue

    patient_num = int(match.group(1))
    patient_id = f"GHANA_ANEMIC_{patient_num:04d}"

    # Retain up to 4 real camera burst exposures per patient
    patient_burst_counter[patient_id] = patient_burst_counter.get(patient_id, 0) + 1
    shot_idx = patient_burst_counter[patient_id]
    if shot_idx > 4:
        continue

    dest_filename = f"anemia_ghana_{patient_id}_shot{shot_idx}{p.suffix.lower()}"
    dest_path = DEST_DIR / dest_filename
    shutil.copy2(p, dest_path)

    try:
        with Image.open(p) as img:
            w, h = img.size
            is_valid = True
    except Exception:
        w, h = None, None
        is_valid = False

    records_anemia.append({
        'source_dataset': 'ghana_mendeley_clinical',
        'file_name': dest_filename,
        'file_path': str(dest_path),
        'image_stem': dest_path.stem,
        'patient_id': patient_id,
        'clinical_condition': 'anemia_palmar_pallor',
        'annotation_stage': None,
        'oral_site': None,
        'body_location': 'palm',
        'capture_type': 'clinical_mobile_burst',
        'width': w,
        'height': h,
        'is_valid_image': is_valid,
        'annotation_count': 0,
        'total_annotated_points': 0
    })

# 4. Merge Expanded Anemia with Healthy Controls
df_anemia_expanded = pd.DataFrame(records_anemia)
df_updated_nb1 = pd.concat([df_healthy, df_anemia_expanded], ignore_index=True)
df_updated_nb1.to_csv(csv_path, index=False)

print("\n" + "=" * 55)
print("NOTEBOOK 1: DATA BALANCING COMPLETE")
print("=" * 55)
print(f"Total authentic anemic captures extracted: {len(df_anemia_expanded)}")
print(f"Unique patient identities represented: {df_anemia_expanded['patient_id'].nunique()}")
print("\nUpdated distribution in Notebook 1:")
print(df_updated_nb1['clinical_condition'].value_counts())
# Out:
# Retained healthy palm controls: 1222
# Total raw anemic files found in Palm folder: 3702
#
# =======================================================
# NOTEBOOK 1: DATA BALANCING COMPLETE
# =======================================================
# Total authentic anemic captures extracted: 1044
# Unique patient identities represented: 261
#
# Updated distribution in Notebook 1:
# clinical_condition
# healthy_palm_control    1222
# anemia_palmar_pallor    1044
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path

# 1. Load standardized metadata registry
csv_path = Path("/kaggle/working/ghana_palm_standardized.csv")
assert csv_path.exists(), "Metadata registry CSV not found!"

df = pd.read_csv(csv_path)

# 2. Sample  random images from each class 
SAMPLES_PER_CLASS = 4
classes = df['clinical_condition'].unique()

sampled_df = (
    df.groupby('clinical_condition', group_keys=False)
    .apply(lambda x: x.sample(n=min(len(x), SAMPLES_PER_CLASS), random_state=None))
    .reset_index(drop=True)
)

# 3. Render 2x4 image verification grid
fig, axes = plt.subplots(len(classes), SAMPLES_PER_CLASS, figsize=(16, 8))
fig.suptitle("GLANCE Palm Cohort  Random Patient Verification", fontsize=16, fontweight='bold', y=0.98)

for row_idx, cls_name in enumerate(classes):
    cls_subset = sampled_df[sampled_df['clinical_condition'] == cls_name].reset_index(drop=True)
    
    for col_idx in range(SAMPLES_PER_CLASS):
        ax = axes[row_idx, col_idx] if len(classes) > 1 else axes[col_idx]
        
        if col_idx < len(cls_subset):
            item = cls_subset.iloc[col_idx]
            img_path = Path(item['file_path'])
            
            if img_path.exists():
                with Image.open(img_path) as img:
                    ax.imshow(img)
                title = f"{item['clinical_condition']}\nID: {item['patient_id']}\nRes: {item['width']}x{item['height']}"
                ax.set_title(title, fontsize=9, pad=6)
            else:
                ax.text(0.5, 0.5, "Image Not Found", ha='center', va='center')
        
        ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_24/2227481929.py:18: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=min(len(x), SAMPLES_PER_CLASS), random_state=None))
